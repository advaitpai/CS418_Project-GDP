# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## FDI Inflow

# %%
fdi_in = pd.read_csv('../data/uncleaned/FDI_inflow.csv')
fdi_in.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code  \
# 0  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 1  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 2  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 3  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
# 4  Foreign direct investment, net inflows (% of GDP)  BX.KLT.DINV.WD.GD.ZS
#
#    1960  1961  1962  1963  1964  1965  ...      2013      2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  8.298275  8.979311  -0.971131
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  2.191682  2.760111   3.118410
# ...

# %%
fdi_in.shape
# Out:
# (266, 67)

# %%
fdi_in.nunique()
# Out:
# Country Name      266
# Country Code      266
# Indicator Name      1
# Indicator Code      1
# 1960                0
#                  ...
# 2018              239
# 2019              237
# 2020              235
# 2021              234
# Unnamed: 66         0
# Length: 67, dtype: int64

# %%
fdi_in = fdi_in.drop(columns = ['Country Name','Indicator Name','Indicator Code','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','Unnamed: 66'])
fdi_in
# Out:
#     Country Code      1970      1971      1972      1973      1974      1975  \
# 0            ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1            AFE  1.110449  0.832667  0.452925  0.272549  1.234468  0.399892
# 2            AFG  0.013151  0.024575  0.009401  0.015577       NaN       NaN
# 3            AFW  1.562941  2.095359  1.862607  1.869109  1.069687  1.573802
# 4            AGO       NaN       NaN       NaN       NaN       NaN       NaN
# ..           ...       ...       ...       ...       ...       ...       ...
# 261          XKX       NaN       NaN       NaN       NaN       NaN       NaN
# 262          YEM       NaN       NaN       NaN       NaN       NaN       NaN
# 263          ZAF  1.576933  1.110846  0.466955  0.082312  1.681897  0.438071
# 264          ZMB  0.521562  0.499111  1.517757  1.410491  1.217233  1.451120
# 265          ZWE  0.990868  1.002425  0.877236  0.921328  0.837485  0.660444
#
# ...

# %%
fdi_in = fdi_in.rename(columns = {"Country Code":"LOCATION"})

# %%
# fdi = fdi.stack()
# fdi.to_frame()
fdi_in = fdi_in.melt(id_vars=["LOCATION"], 
        var_name="TIME", 
        value_name="FDI_IN")
fdi_in
# Out:
#       LOCATION  TIME    FDI_IN
# 0          ABW  1970       NaN
# 1          AFE  1970  1.110449
# 2          AFG  1970  0.013151
# 3          AFW  1970  1.562941
# 4          AGO  1970       NaN
# ...        ...   ...       ...
# 13827      XKX  2021  5.322207
# 13828      YEM  2021       NaN
# 13829      ZAF  2021  9.855527
# 13830      ZMB  2021 -3.716346
# 13831      ZWE  2021  0.585100
#
# [13832 rows x 3 columns]

# %% [markdown]
# ## FDI Outflow

# %%
fdi_out = pd.read_csv('../data/uncleaned/FDI_outflow.csv')
fdi_out.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name        Indicator Code  \
# 0  Foreign direct investment, net outflows (% of ...  BM.KLT.DINV.WD.GD.ZS
# 1  Foreign direct investment, net outflows (% of ...  BM.KLT.DINV.WD.GD.ZS
# 2  Foreign direct investment, net outflows (% of ...  BM.KLT.DINV.WD.GD.ZS
# 3  Foreign direct investment, net outflows (% of ...  BM.KLT.DINV.WD.GD.ZS
# 4  Foreign direct investment, net outflows (% of ...  BM.KLT.DINV.WD.GD.ZS
#
#    1960  1961  1962  1963  1964  1965  ...      2013      2014      2015  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN  ...  0.162021  0.317597  0.354854
# 1   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.159402  1.058701  0.802633
# ...

# %%
fdi_out.shape
# Out:
# (266, 67)

# %%
fdi_out.nunique()
# Out:
# Country Name      266
# Country Code      266
# Indicator Name      1
# Indicator Code      1
# 1960                0
#                  ...
# 2018              216
# 2019              214
# 2020              211
# 2021              210
# Unnamed: 66         0
# Length: 67, dtype: int64

# %%
fdi_out = fdi_out.drop(columns = ['Country Name','Indicator Name','Indicator Code','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','Unnamed: 66'])
fdi_out
# Out:
#     Country Code      1970      1971      1972      1973      1974      1975  \
# 0            ABW       NaN       NaN       NaN       NaN       NaN       NaN
# 1            AFE       NaN       NaN       NaN       NaN       NaN       NaN
# 2            AFG       NaN       NaN       NaN       NaN       NaN       NaN
# 3            AFW       NaN       NaN       NaN       NaN       NaN       NaN
# 4            AGO       NaN       NaN       NaN       NaN       NaN       NaN
# ..           ...       ...       ...       ...       ...       ...       ...
# 261          XKX       NaN       NaN       NaN       NaN       NaN       NaN
# 262          YEM       NaN       NaN       NaN       NaN       NaN       NaN
# 263          ZAF  0.079177  0.125418  0.079595  0.155959  0.277353  0.293098
# 264          ZMB       NaN       NaN       NaN       NaN       NaN       NaN
# 265          ZWE       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
fdi_out = fdi_out.rename(columns = {"Country Code":"LOCATION"})

# %%
fdi_out = fdi_out.melt(id_vars=["LOCATION"], 
        var_name="TIME", 
        value_name="FDI_OUT")
fdi_out
# Out:
#       LOCATION  TIME   FDI_OUT
# 0          ABW  1970       NaN
# 1          AFE  1970       NaN
# 2          AFG  1970       NaN
# 3          AFW  1970       NaN
# 4          AGO  1970       NaN
# ...        ...   ...       ...
# 13827      XKX  2021  1.261958
# 13828      YEM  2021       NaN
# 13829      ZAF  2021 -0.001536
# 13830      ZMB  2021 -2.277041
# 13831      ZWE  2021  0.193858
#
# [13832 rows x 3 columns]

# %%
fdi = pd.merge(fdi_in,fdi_out)
fdi['Value'] = fdi['FDI_IN'] - fdi['FDI_OUT']
fdi
# Out:
#       LOCATION  TIME    FDI_IN   FDI_OUT     Value
# 0          ABW  1970       NaN       NaN       NaN
# 1          AFE  1970  1.110449       NaN       NaN
# 2          AFG  1970  0.013151       NaN       NaN
# 3          AFW  1970  1.562941       NaN       NaN
# 4          AGO  1970       NaN       NaN       NaN
# ...        ...   ...       ...       ...       ...
# 13827      XKX  2021  5.322207  1.261958  4.060249
# 13828      YEM  2021       NaN       NaN       NaN
# 13829      ZAF  2021  9.855527 -0.001536  9.857063
# 13830      ZMB  2021 -3.716346 -2.277041 -1.439305
# 13831      ZWE  2021  0.585100  0.193858  0.391241
#
# [13832 rows x 5 columns]

# %%
fdi=fdi.drop(columns=['FDI_IN','FDI_OUT'])
fdi
# Out:
#       LOCATION  TIME     Value
# 0          ABW  1970       NaN
# 1          AFE  1970       NaN
# 2          AFG  1970       NaN
# 3          AFW  1970       NaN
# 4          AGO  1970       NaN
# ...        ...   ...       ...
# 13827      XKX  2021  4.060249
# 13828      YEM  2021       NaN
# 13829      ZAF  2021  9.857063
# 13830      ZMB  2021 -1.439305
# 13831      ZWE  2021  0.391241
#
# [13832 rows x 3 columns]
